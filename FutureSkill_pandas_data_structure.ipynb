# %% [markdown]
# <a href="https://colab.research.google.com/github/dianakang/DIANA_Pandas/blob/master/FutureSkill_pandas_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   출처:
# FutureSkill 웹사이트
#
#
# https://www.futureskill.io/dashboard

# %% [markdown]
# # 1번 문제

# %% [markdown]
# Q.
# 주어진 Python list L 을 Pandas series 로 변환하는 코드를 작성해보세요.

# %%
# # 베이스라인
# import pandas as pd # pandas 라이브러리를 불러옵니다.

# L = [1, 2, 3, 4, 5]

# '''
# code here
# '''

# %% [markdown]
# ![Screen Shot 2021-03-02 at 9.45.08 PM.png](data:image/png;base64,...)

# %%
# 답
import pandas as pd # pandas 라이브러리를 불러옵니다.

L = [1, 2, 3, 4, 5]

seriesL = pd.Series(L)
seriesL
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# # 2번 문제

# %% [markdown]
# 열의 이름은 A, B, C, D이고 각 열마다 5개의 random한(임의의) 숫자를 원소로 하는 DataFrame을 생성하는 코드를 작성해보세요.
# ![Screen Shot 2021-03-02 at 9.46.38 PM.png](data:image/png;base64,...)

# %%
# 답
import numpy as np
import random

a = pd.DataFrame(np.random.rand(5,4))
a.columns = ['A', 'B', 'C', 'D']
a
# Out:
#           A         B         C         D
# 0  0.757981  0.111400  0.126704  0.392873
# 1  0.519659  0.846627  0.170125  0.814919
# 2  0.078800  0.012058  0.557203  0.536837
# 3  0.330205  0.393006  0.669460  0.729643
# 4  0.298759  0.209194  0.584617  0.479530

# %% [markdown]
# ---
#
#
#
# *   도움 얻은 사이트
# : https://blog.naver.com/bya135/222204277925

# %%
# 위의 문제에서 활용된 개념

## 새로운 데이터 프레임 생성하기
## df = pd.DataFrame({'인덱스1':[값1, 값2], '인덱스2':[값1, 값2]})

# %%
# 위의 문제에서 활용된 개념

## 행/열에 랜덤 숫자를 가져가는 새로운 데이터 프레임 만들기
## import numpy as np
## pd.DataFrame(np.random.rand(행갯수,열갯수))

# %% [markdown]
# # 3번 문제

# %% [markdown]
# *   안내
#
# 이번 문제에서 생성한 DataFrame은 pandas 기본 콘텐츠 내에서 계속해서 활용될 예정입니다. 앞으로는 이 DataFrame을 지칭할 때는 df_A 라고 하겠습니다.
#
# *   문제
#
# 2번 문제에서 생성한 DataFrame의 index로 2020년 1월 1일 부터 2020년 1월 5일까지의 날짜를 지정하는 코드를 작성해보세요.
#
# ![Screen Shot 2021-03-02 at 10.17.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# *   검색키워드
#
#
# pandas dataframe with datetime, pandas index daterange, pandas set index

# %%
a = pd.DataFrame(np.random.rand(5,4))
a.columns = ['A', 'B', 'C', 'D']
a.index = pd.date_range(start='20200101', end='20200105')
a
# Out:
#                    A         B         C         D
# 2020-01-01  0.497607  0.336248  0.413802  0.296094
# 2020-01-02  0.680115  0.083669  0.932033  0.119542
# 2020-01-03  0.898201  0.007897  0.108573  0.832771
# 2020-01-04  0.345657  0.061919  0.567721  0.566312
# 2020-01-05  0.861756  0.904525  0.101158  0.764872
